# %%
import random
import time
from IPython.display import Image, display

#Game Instruction
print('\033[1;30mWelcome to Pokemon Battle\033[m')
a=int(input('Enter 0 to start. If you want to see HOW TO PLAY type 1: '))
if a==0:
    pass
if a==1:
    print('It is Pokemon Battle Game. First you will choose a pokemon between Bulbasaur, Charmander, Squirtle.\nTo attack you need to win Rock, Paper and scissors.\nIf you win it you can choose your attack (1 is Basic Attack, 2 is your Pokemon`s skil).\nYou can use just 4 times your second skil\nIf you win 3 times in a row you can use your special pokemon skil.')

#Playes names input    
player=input('Pokemon Trainer! What`s your name? ').lower().capitalize().strip()
print(f'\033[1;30mWelcome to Pokemon World \033[4;30m{player}\033[m')

opponent_player=input('What`s your opponent name? ').lower().capitalize().strip()


#Setting Pokemon
pokemon=['Bulbasaur','Charmander','Squirtle']
while True:
    your_pokemon=input('It`s time to start your journey with Pokemon.Choose your Pokemon\033[1;30m(Bulbasaur, Charmander, Squirtle):\033[m ').lower().capitalize().strip()
    if your_pokemon in pokemon:
        break
    else:
        print('Choose your pokemon one of them \033[1;30m(Bulbasaur, Charmander, Squirtle)\033[m')
print(f'{player} chose \033[4;30m{your_pokemon}\033[m')
if your_pokemon=='Bulbasaur':
    n_your_pokemon=0
if your_pokemon=='Charmander':
    n_your_pokemon=1
if your_pokemon=='Squirtle':
    n_your_pokemon=2
    
if your_pokemon=='Charmander':
    listOfImageNames = ['charmander.png']

    for imageName in listOfImageNames:
        display(Image(filename='charmander.png', width = 250))
if your_pokemon=='Bulbasaur':
    listOfImageNames = ['bulbasaur.png']

    for imageName in listOfImageNames:
        display(Image(filename='bulbasaur.png', width = 250))
if your_pokemon=='Squirtle':
    listOfImageNames = ['squirtle.jpg']

    for imageName in listOfImageNames:
        display(Image(filename='squirtle.jpg', width = 250))

pokemon.remove(your_pokemon)
opponent_pokemon=pokemon[random.randint(0,1)]
print('.')
time.sleep(1)
print('.')
time.sleep(1)
print('.')

print(f'{opponent_player} chose \033[4;30m{opponent_pokemon}\033[m') 

if opponent_pokemon=='Bulbasaur':
    n_opponent_pokemon=0
if opponent_pokemon=='Charmander':
    n_opponent_pokemon=1
if opponent_pokemon=='Squirtle':
    n_opponent_pokemon=2
    
if opponent_pokemon=='Charmander':
    listOfImageNames = ['charmander.png']

    for imageName in listOfImageNames:
        display(Image(filename='charmander.png', width = 250))
if opponent_pokemon=='Bulbasaur':
    listOfImageNames = ['bulbasaur.png']

    for imageName in listOfImageNames:
        display(Image(filename='bulbasaur.png', width = 250))
if opponent_pokemon=='Squirtle':
    listOfImageNames = ['squirtle.jpg']

    for imageName in listOfImageNames:
        display(Image(filename='squirtle.jpg', width = 250))

#Setting Skils
bulbasaur={1:'Tackle',2:'Vine Whip'}
charmander={1:'Scratch',2:'Ember'}
squirtle={1:'Tackle',2:'Water Gun'}
pokemon_skil=[bulbasaur,charmander,squirtle]
special=['Solar Beam','Fire Blast','Hydro Pump']

#story telling
print(f'{opponent_player}: Hey {player} Let`s check out our Pokemon!')
time.sleep(0.5)
print(f'{opponent_player} wants to fight with you...')
print('------------------------------------------------')
time.sleep(0.5)


#Rock, paper, Scissors Def function
winer=''
player_special_skil=0
comp_special_skil=0
def win():
    gestures=['Rock','Paper','Scissors']
    global winer
    global player_special_skil
    global comp_special_skil
    
    while True:
        comp_choice=random.choice(gestures)
        while True:
            player_choice = input('What is your choice? You must choose one of them (Rock, Paper, Scissors):  ').lower().capitalize().strip()
            if player_choice in gestures:
                break
        time.sleep(1)
        if player_choice==comp_choice:
            print('TIE!')
        if player_choice == 'Rock':
                if comp_choice == 'Paper':
                        winer = 'comp'
                        print(f'{opponent_player} choose {comp_choice}')
                        print('-----------------------------------------------------')
                        print('\033[1;33;40mYou Lose\033[m')
                        time.sleep(0.5)
                        comp_special_skil+=1
                        player_special_skil=0
                        break
                elif comp_choice == 'Scissors':
                        winer = 'player'
                        print(f'{opponent_player} choose {comp_choice}')
                        print('-----------------------------------------------------')
                        print('\033[7;37;40mYou Win\033[m')
                        time.sleep(0.5)
                        comp_special_skil=0
                        player_special_skil+=1
                        break
        if player_choice == 'Paper':
                if comp_choice == 'Rock':
                        winer = 'player'
                        print(f'{opponent_player} choose {comp_choice}')
                        print('-----------------------------------------------------')
                        print('\033[7;37;40mYou Win\033[m')
                        time.sleep(0.5)
                        comp_special_skil=0
                        player_special_skil+=1
                        break
                elif comp_choice == 'Scissors':
                        winer = 'comp'
                        print(f'{opponent_player} choose {comp_choice}')
                        print('-----------------------------------------------------')
                        print('\033[1;33;40mYou Lose\033[m')
                        time.sleep(0.5)
                        comp_special_skil+=1
                        player_special_skil=0
                        break
        if player_choice == 'Scissors':
                if comp_choice == 'Rock':
                        winer = 'comp'
                        print(f'{opponent_player} choose {comp_choice}')
                        print('-----------------------------------------------------')
                        print('\033[1;33;40mYou Lose\033[m')
                        time.sleep(0.5)
                        comp_special_skil+=1
                        player_special_skil=0
                        break
                elif comp_choice == 'Paper':
                        winer = 'player'
                        print(f'{opponent_player} choose {comp_choice}')
                        print('-----------------------------------------------------')
                        print('\033[7;37;40mYou Win\033[m')
                        time.sleep(0.5)
                        comp_special_skil=0
                        player_special_skil+=1
                        break

#Battle Setting
your_hp=150
opponent_hp=150                        
second_skil=3
while True:
    if opponent_hp<=0 or your_hp<=0:
        break
    else:
        win()
        time.sleep(0.5)
        if winer=='player':
            if opponent_hp<=0 or your_hp<=0:
                break
            if player_special_skil%3==0:
                print('You won 3 times in a row!')
                print(f'You can use {special[n_your_pokemon]}')
                time.sleep(1)
                opponent_hp=opponent_hp-50
                print(f'{your_pokemon} used {special[n_your_pokemon]} to {opponent_pokemon}')
                time.sleep(1)
                print(f'{player}: {your_pokemon}! I choose you! {special[n_your_pokemon].upper()}.!!!!!!')
            else:
                print('-----------------------------------------------------')
                print(f'Chose your attack {pokemon_skil[n_your_pokemon]}',end='')
                time.sleep(0.5)
                skil=int(input(': '))

                if skil==1:
                    print(f'{your_pokemon} used {pokemon_skil[n_your_pokemon][skil]} to {opponent_pokemon}')
                    opponent_hp=opponent_hp-10
                if skil==2:
                    if second_skil<0:
                        print(f'{your_pokemon} always used {pokemon_skil[n_your_pokemon][2]} 3 times.')
                        print(f'{your_pokemon} can`t use {pokemon_skil[n_your_pokemon][2]} more')
                        print(f'{your_pokemon} used {pokemon_skil[n_your_pokemon][1]} to {opponent_pokemon}')
                        opponent_hp=opponent_hp-10
                    else:   
                        print(f'{your_pokemon} used {pokemon_skil[n_your_pokemon][skil]} to {opponent_pokemon}')
                        second_skil=second_skil-1
                        if your_pokemon=='Bulbasaur':
                            if opponent_pokemon=='Charmander':
                                time.sleep(1)
                                print('But it was not efficient...')
                                opponent_hp=opponent_hp-20
                            if opponent_pokemon=='Squirtle':
                                time.sleep(1)
                                print('It was efficient!!!')
                                opponent_hp=opponent_hp-30
                        if your_pokemon=='Charmander':
                            if opponent_pokemon=='Squirtle':
                                time.sleep(1)
                                print('But it was not efficient...')
                                opponent_hp=opponent_hp-20
                            if opponent_pokemon=='Bulbasaur':
                                time.sleep(1)
                                print('It was efficient!!!')
                                opponent_hp=opponent_hp-30
                        if your_pokemon=='Squirtle':
                            if opponent_pokemon=='Charmander':
                                time.sleep(1)
                                print('It was efficient!!!')
                                opponent_hp=opponent_hp-30
                            if opponent_pokemon=='Bulbasaur':
                                time.sleep(1)
                                print('But it was not efficient...')
                                opponent_hp=opponent_hp-20
            time.sleep(1)
            print('-----------------------------------------------------')
            print(f'{your_pokemon} HP {your_hp:.>20}')
            print(f'{opponent_pokemon} HP {opponent_hp:.>20}')
            print('-----------------------------------------------------')

        if winer=='comp':
            if opponent_hp<=0 or your_hp<=0:
                break
            if comp_special_skil%3==0:
                print(f'{opponent_player} won 3 times in a row!')
                print(f'He can use {special[n_opponent_pokemon]}')
                your_hp=your_hp-50
                print(f'{opponent_pokemon} used {special[n_opponent_pokemon]} to {your_pokemon}')
                time.sleep(0.5)
                print(f'{opponent_player}: {opponent_pokemon}! I choose you! {special[n_opponent_pokemon].upper()}.!!!!!!')
            else:
                skil=random.randint(1,2)
                if second_skil<0 and skil==2:
                    print(f'{opponent_pokemon} used {pokemon_skil[n_opponent_pokemon][1]} to {your_pokemon}')
                    your_hp=your_hp-10
                if skil==1:
                    print(f'{opponent_pokemon} used {pokemon_skil[n_opponent_pokemon][skil]} to {your_pokemon}')
                    your_hp=your_hp-10
                if skil==2 and second_skil>0:
                    print(f'{opponent_pokemon} used {pokemon_skil[n_opponent_pokemon][skil]} to {your_pokemon}')
                    if opponent_pokemon=='Bulbasaur':
                        if your_pokemon=='Charmander':
                            time.sleep(1)
                            print('But it was not efficient...')
                            your_hp=your_hp-20
                        if your_pokemon=='Squirtle':
                            time.sleep(1)
                            print('It was efficient!!!')
                            your_hp=your_hp-30
                    if opponent_pokemon=='Charmander':
                        if your_pokemon=='Squirtle':
                            time.sleep(1)
                            print('But it was not efficient...')
                            your_hp=your_hp-20
                        if your_pokemon=='Bulbasaur':
                            time.sleep(1)
                            print('It was efficient!!!')
                            your_hp=your_hp-30
                    if opponent_pokemon=='Squirtle':
                        if your_pokemon=='Charmander':
                            time.sleep(1)
                            print('It was efficient!!!')
                            your_hp=your_hp-30
                        if your_pokemon=='Bulbasaur':
                            time.sleep(1)
                            print('But it was not efficient...')
                            your_hp=your_hp-20
            time.sleep(1)
            print('-----------------------------------------------------')
            print(f'{your_pokemon} HP {your_hp:.>20}')
            print(f'{opponent_pokemon} HP {opponent_hp:.>20}')
            print('-----------------------------------------------------')
            
print('...')
time.sleep(1)        
print('...')
time.sleep(1)        
print('...')
time.sleep(1)        
        
if your_hp>opponent_hp:
    print(f'{player}, {your_pokemon} WIN!')
else:
    print(f'{opponent_player}, {opponent_pokemon} WIN!')
# Out:
# Welcome to Pokemon Battle
# Enter 0 to start. If you want to see HOW TO PLAY type 1: 1
# It is Pokemon Battle Game. First you will choose a pokemon between Bulbasaur, Charmander, Squirtle.
# To attack you need to win Rock, Paper and scissors.
# If you win it you can choose your attack (1 is Basic Attack, 2 is your Pokemon`s skil).
# You can use just 4 times your second skil
# If you win 3 times in a row you can use your special pokemon skil.
# Pokemon Trainer! What`s your name? luis
# Welcome to Pokemon World Luis
# What`s your opponent name? ronaldo
# It`s time to start your journey with Pokemon.Choose your Pokemon(Bulbasaur, Charmander, Squirtle): chramander
# Choose your pokemon one of them (Bulbasaur, Charmander, Squirtle)
# It`s time to start your journey with Pokemon.Choose your Pokemon(Bulbasaur, Charmander, Squirtle): charmander
# Luis chose Charmander
# .
# .
# .
# Ronaldo chose Bulbasaur
# Ronaldo: Hey Luis Let`s check out our Pokemon!
# Ronaldo wants to fight with you...
# ...
