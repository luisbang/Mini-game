# %%
import random
import time

player=input('Pokemon Trainer! What`s your name? ').lower().capitalize().strip()
print(f'Welcome to Pokemon World {player}')

opponent_player=input('What`s his name? ').lower().capitalize().strip()


pokemon=['Bulbasaur','Charmander','Squirtle']
while True:
    your_pokemon=input('its time to venture with your pokemon! Choose your pokemon (Bulbasaur, Charmander, Squirtle): ').lower().capitalize().strip()
    if your_pokemon in pokemon:
        break
    else:
        print('Choose your pokemon one of them (Bulbasaur, Charmander, Squirtle)')
print(f'{player} choose {your_pokemon}')
if your_pokemon=='Bulbasaur':
    n_your_pokemon=0
if your_pokemon=='Charmander':
    n_your_pokemon=1
if your_pokemon=='Squirtle':
    n_your_pokemon=2
     
pokemon.remove(your_pokemon)
opponent_pokemon=pokemon[random.randint(0,1)]
print('.')
time.sleep(1)
print('.')
time.sleep(1)
print('.')

print(f'{opponent_player} choose {opponent_pokemon}') 

if opponent_pokemon=='Bulbasaur':
    n_opponent_pokemon=0
if opponent_pokemon=='Charmander':
    n_opponent_pokemon=1
if opponent_pokemon=='Squirtle':
    n_opponent_pokemon=2

bulbasaur={1:'Tackle',2:'Vine Whip',3:'Solar Beam'}
charmander={1:'Scratch',2:'Ember',3:'Fire Blast'}
squirtle={1:'Tackle',2:'Water Gun',3:'Hydro Pump'}
pokemon_stkil=[bulbasaur,charmander,squirtle]


winer=''
special_skil=0
def win():
    gestures=['Rock','Paper','Scissors']
    global winer
    while True:
        comp_choice=random.choice(gestures)
        player_choice = input('What is your choice? You must choose one of them (rock, paper, scissors):  ').lower().capitalize().strip()
        time.sleep(1)
        if player_choice==comp_choice:
            print('TIE!')
        if player_choice == 'Rock':
                if comp_choice == 'Paper':
                        winer = 'comp'
                        print(f'{opponent_player} choose {comp_choice}')
                        print('-----------------------------------------------------')
                        print('You Lose')
                        time.sleep(0.5)
                        break
                elif comp_choice == 'Scissors':
                        winer = 'player'
                        print(f'{opponent_player} choose {comp_choice}')
                        print('-----------------------------------------------------')
                        print('You win')
                        time.sleep(0.5)
                        break
        if player_choice == 'Paper':
                if comp_choice == 'Rock':
                        winer = 'player'
                        print(f'{opponent_player} choose {comp_choice}')
                        print('-----------------------------------------------------')
                        print('You win')
                        time.sleep(0.5)
                        break
                elif comp_choice == 'Scissors':
                        winer = 'comp'
                        print(f'{opponent_player} choose {comp_choice}')
                        print('-----------------------------------------------------')
                        print('You Lose')
                        time.sleep(0.5)
                        break
        if player_choice == 'Scissors':
                if comp_choice == 'Rock':
                        winer = 'comp'
                        print(f'{opponent_player} choose {comp_choice}')
                        print('-----------------------------------------------------')
                        print('You Lose')
                        time.sleep(0.5)
                        break
                elif comp_choice == 'Paper':
                        winer = 'player'
                        print(f'{opponent_player} choose {comp_choice}')
                        print('-----------------------------------------------------')
                        print('You win')
                        time.sleep(0.5)
                        break


your_hp=100
opponent_hp=100                        

while True:
    
    win()
    if winer=='player':
        print('-----------------------------------------------------')
        print(f'Chose your attack {pokemon_skil[n_your_pokemon]}',end='')
        skil=int(input(': '))
        print(f'{your_pokemon} used {pokemon_skil[n_your_pokemon][skil]} to {opponent_pokemon}')
        if skil==1:
            opponent_hp=opponent_hp-10
        if skil==2:
            if your_pokemon=='Bulbasaur':
                if opponent_pokemon=='Charmander':
                    print('But it was not efficient...')
                    opponent_hp=opponent_hp-20
                if opponent_pokemon=='Squirtle':
                    print('It was efficient!!!')
                    opponent_hp=opponent_hp-30
            if your_pokemon=='Charmander':
                if opponent_pokemon=='Squirtle':
                    print('But it was not efficient...')
                    opponent_hp=opponent_hp-20
                if opponent_pokemon=='Bulbasaur':
                    print('It was efficient!!!')
                    opponent_hp=opponent_hp-30
            if your_pokemon=='Squirtle':
                if opponent_pokemon=='Charmander':
                    print('It was efficient!!!')
                    opponent_hp=opponent_hp-30
                if opponent_pokemon=='Bulbasaur':
                    print('But it was not efficient...')
                    opponent_hp=opponent_hp-20
    
        if opponent_hp<0 or your_hp<0:
            break
        else:
            print('-----------------------------------------------------')
            print(f'your HP {your_hp}')
            print(f'opponent HP {opponent_hp}')
            print('-----------------------------------------------------')
    if winer=='comp':
        skil=random.randint(1,2)
        print(f'{opponent_pokemon} used {pokemon_skil[n_your_pokemon][skil]} to {your_pokemon}')
        if skil==1:
            your_hp=your_hp-10
        if skil==2:
            if opponent_pokemon=='Bulbasaur':
                if your_pokemon=='Charmander':
                    print('But it was not efficient...')
                    your_hp=your_hp-20
                if your_pokemon=='Squirtle':
                    print('It was efficient!!!')
                    your_hp=your_hp-30
            if opponent_pokemon=='Charmander':
                if your_pokemon=='Squirtle':
                    print('But it was not efficient...')
                    your_hp=your_hp-20
                if your_pokemon=='Bulbasaur':
                    print('It was efficient!!!')
                    your_hp=your_hp-30
            if opponent_pokemon=='Squirtle':
                if your_pokemon=='Charmander':
                    print('It was efficient!!!')
                    your_hp=your_hp-30
                if your_pokemon=='Bulbasaur':
                    print('But it was not efficient...')
                    your_hp=your_hp-20
  

        if opponent_hp<0 or your_hp<0:
            break
        else:
            print('-----------------------------------------------------')
            print(f'your HP {your_hp}')
            print(f'opponent HP {opponent_hp}')
            print('-----------------------------------------------------')
# Out:
# Pokemon Trainer! What`s your name? LUIS
# Welcome to Pokemon World Luis
# What`s his name? cati
# its time to venture with your pokemon! Choose your pokemon (Bulbasaur, Charmander, Squirtle): charmander
# Luis choose Charmander
# .
# .
# .
# Cati choose Squirtle
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-159-cc0564b8433c> in <module>
#     111 while True:
#     112
# --> 113     win()
#     114     if winer=='player':
#     115         print('-----------------------------------------------------')
#
# <ipython-input-159-cc0564b8433c> in win()
#      55
#      56
# ---> 57         player_choice = input('What is your choice? You must choose one of them (rock, paper, scissors):  ').lower().capitalize().strip()
#      58         time.sleep(1)
#      59         if player_choice==comp_choice:
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
print('\033[0;30;41mOlá, Mundo\033[m')
# Out:
# Olá, Mundo

# %%
import random
import time

player=input('Pokemon Trainer! What`s your name? ').lower().capitalize().strip()
print(f'Welcome to Pokemon World {player}')

opponent_player=input('What`s his name? ').lower().capitalize().strip()


pokemon=['Bulbasaur','Charmander','Squirtle']
while True:
    your_pokemon=input('its time to venture with your pokemon! Choose your pokemon (Bulbasaur, Charmander, Squirtle): ').lower().capitalize().strip()
    if your_pokemon in pokemon:
        break
    else:
        print('Choose your pokemon one of them (Bulbasaur, Charmander, Squirtle)')
print(f'{player} choose {your_pokemon}')
if your_pokemon=='Bulbasaur':
    n_your_pokemon=0
if your_pokemon=='Charmander':
    n_your_pokemon=1
if your_pokemon=='Squirtle':
    n_your_pokemon=2
     
pokemon.remove(your_pokemon)
opponent_pokemon=pokemon[random.randint(0,1)]
print('.')
time.sleep(1)
print('.')
time.sleep(1)
print('.')

print(f'{opponent_player} choose {opponent_pokemon}') 

if opponent_pokemon=='Bulbasaur':
    n_opponent_pokemon=0
if opponent_pokemon=='Charmander':
    n_opponent_pokemon=1
if opponent_pokemon=='Squirtle':
    n_opponent_pokemon=2

bulbasaur={1:'Tackle',2:'Vine Whip',3:'Solar Beam'}
charmander={1:'Scratch',2:'Ember',3:'Fire Blast'}
squirtle={1:'Tackle',2:'Water Gun',3:'Hydro Pump'}
pokemon_skil=[bulbasaur,charmander,squirtle]


winer=''
player_special_skil=0
comp_special_skil=0
def win():
    gestures=['Rock','Paper','Scissors']
    global winer
    global player_special_skil
    global comp_special_skil
    
    while True:
        comp_choice=random.choice(gestures)
        while True:
            player_choice = input('What is your choice? You must choose one of them (rock, paper, scissors):  ').lower().capitalize().strip()
            if player_choice in gestures:
                break
        time.sleep(1)
        if player_choice==comp_choice:
            print('TIE!')
        if player_choice == 'Rock':
                if comp_choice == 'Paper':
                        winer = 'comp'
                        print(f'{opponent_player} choose {comp_choice}')
                        print('-----------------------------------------------------')
                        print('You Lose')
                        time.sleep(0.5)
                        comp_special_skil+=1
                        player_special_skil=0
                        time.sleep(0.5)
                        break
                elif comp_choice == 'Scissors':
                        winer = 'player'
                        print(f'{opponent_player} choose {comp_choice}')
                        print('-----------------------------------------------------')
                        print('You win')
                        time.sleep(0.5)
                        comp_special_skil=0
                        player_special_skil+=1
                        time.sleep(0.5)
                        break
        if player_choice == 'Paper':
                if comp_choice == 'Rock':
                        winer = 'player'
                        print(f'{opponent_player} choose {comp_choice}')
                        print('-----------------------------------------------------')
                        print('You win')
                        time.sleep(0.5)
                        comp_special_skil=0
                        player_special_skil+=1
                        time.sleep(0.5)
                        break
                elif comp_choice == 'Scissors':
                        winer = 'comp'
                        print(f'{opponent_player} choose {comp_choice}')
                        print('-----------------------------------------------------')
                        print('You Lose')
                        time.sleep(0.5)
                        comp_special_skil+=1
                        player_special_skil=0
                        time.sleep(0.5)
                        break
        if player_choice == 'Scissors':
                if comp_choice == 'Rock':
                        winer = 'comp'
                        print(f'{opponent_player} choose {comp_choice}')
                        print('-----------------------------------------------------')
                        print('You Lose')
                        time.sleep(0.5)
                        comp_special_skil+=1
                        player_special_skil=0
                        time.sleep(0.5)
                        break
                elif comp_choice == 'Paper':
                        winer = 'player'
                        print(f'{opponent_player} choose {comp_choice}')
                        print('-----------------------------------------------------')
                        print('You win')
                        time.sleep(0.5)
                        comp_special_skil=0
                        player_special_skil+=1
                        time.sleep(0.5)
                        break


your_hp=150
opponent_hp=150                        
second_skil=3
while True:
    if opponent_hp<=0 or your_hp<=0:
        break
    else:
        win()
        if winer=='player':
            if opponent_hp<=0 or your_hp<=0:
                break
            if player_special_skil==3:
                print('You won 3 times in a row!')
                print(f'You can use {pokemon_skil[n_your_pokemon][3]}')
                time.sleep(0.5)
                opponent_hp=opponent_hp-50
                print(f'{your_pokemon} used {pokemon_skil[n_your_pokemon][3]} to {opponent_pokemon}')
                time.sleep(0.5)
                print(f'{player}: {your_pokemon}! I choose you! {pokemon_skil[n_your_pokemon][3].upper()}.!!!!!!')

            else:
                print('-----------------------------------------------------')
                print(f'Chose your attack {pokemon_skil[n_your_pokemon]}',end='')
                time.sleep(0.5)
                skil=int(input(': '))
                if second_skil<0 and skil==2:
                    print(f'{your_pokemon} always used {pokemon_skil[n_your_pokemon][2]} 3 times')
                    print(f'{your_pokemon} used {pokemon_skil[n_your_pokemon][1]} to {opponent_pokemon}')
                    opponent_hp=opponent_hp-10

                if skil==1:
                    print(f'{your_pokemon} used {pokemon_skil[n_your_pokemon][skil]} to {opponent_pokemon}')
                    opponent_hp=opponent_hp-10
                if skil==2:
                    print(f'{your_pokemon} used {pokemon_skil[n_your_pokemon][skil]} to {opponent_pokemon}')
                    second_skil=second_skil-1
                    if your_pokemon=='Bulbasaur':
                        if opponent_pokemon=='Charmander':
                            print('But it was not efficient...')
                            opponent_hp=opponent_hp-20
                        if opponent_pokemon=='Squirtle':
                            print('It was efficient!!!')
                            opponent_hp=opponent_hp-30
                    if your_pokemon=='Charmander':
                        if opponent_pokemon=='Squirtle':
                            print('But it was not efficient...')
                            opponent_hp=opponent_hp-20
                        if opponent_pokemon=='Bulbasaur':
                            print('It was efficient!!!')
                            opponent_hp=opponent_hp-30
                    if your_pokemon=='Squirtle':
                        if opponent_pokemon=='Charmander':
                            print('It was efficient!!!')
                            opponent_hp=opponent_hp-30
                        if opponent_pokemon=='Bulbasaur':
                            print('But it was not efficient...')
                            opponent_hp=opponent_hp-20

            print('-----------------------------------------------------')
            print(f'{your_pokemon} HP {your_hp:.>20}')
            print(f'{opponent_pokemon} HP {opponent_hp:.>20}')
            print('-----------------------------------------------------')

        if winer=='comp':
            if opponent_hp<=0 or your_hp<=0:
                break
            if comp_special_skil==3:
                print(f'{opponent_player} won 3 times in a row!')
                print(f'He can use {pokemon_skil[n_opponent_pokemon][3]}')
                your_hp=your_hp-50
                print(f'{opponent_pokemon} used {pokemon_skil[n_opponent_pokemon][3]} to {your_pokemon}')
                time.sleep(0.5)
                print(f'{opponent_player}: {opponent_pokemon}! I choose you! {pokemon_skil[n_opponent_pokemon][3].upper()}.!!!!!!')
            else:
                skil=random.randint(1,2)
                if second_skil<0 and skil==2:
                    print(f'{opponent_pokemon} used {pokemon_skil[n_opponent_pokemon][1]} to {your_pokemon}')
                    your_hp=your_hp-10
                if skil==1:
                    print(f'{opponent_pokemon} used {pokemon_skil[n_opponent_pokemon][skil]} to {your_pokemon}')
                    your_hp=your_hp-10
                if skil==2:
                    print(f'{opponent_pokemon} used {pokemon_skil[n_opponent_pokemon][skil]} to {your_pokemon}')
                    if opponent_pokemon=='Bulbasaur':
                        if your_pokemon=='Charmander':
                            print('But it was not efficient...')
                            your_hp=your_hp-20
                        if your_pokemon=='Squirtle':
                            print('It was efficient!!!')
                            your_hp=your_hp-30
                    if opponent_pokemon=='Charmander':
                        if your_pokemon=='Squirtle':
                            print('But it was not efficient...')
                            your_hp=your_hp-20
                        if your_pokemon=='Bulbasaur':
                            print('It was efficient!!!')
                            your_hp=your_hp-30
                    if opponent_pokemon=='Squirtle':
                        if your_pokemon=='Charmander':
                            print('It was efficient!!!')
                            your_hp=your_hp-30
                        if your_pokemon=='Bulbasaur':
                            print('But it was not efficient...')
                            your_hp=your_hp-20

            print('-----------------------------------------------------')
            print(f'{your_pokemon} HP {your_hp:.>20}')
            print(f'{opponent_pokemon} HP {opponent_hp:.>20}')
            print('-----------------------------------------------------')
            
print('...')
time.sleep(1)        
print('...')
time.sleep(1)        
print('...')
time.sleep(1)        
        
if your_hp>opponent_hp:
    print(f'{player} WINS!')
else:
    print(f'{opponent_player} WINS!')
# Out:
# Pokemon Trainer! What`s your name? Esther
# Welcome to Pokemon World Esther
# What`s his name? Cati
# its time to venture with your pokemon! Choose your pokemon (Bulbasaur, Charmander, Squirtle): Bulbasaur
# Esther choose Bulbasaur
# .
# .
# .
# Cati choose Squirtle
# What is your choice? You must choose one of them (rock, paper, scissors):  paper
# Cati choose Rock
# -----------------------------------------------------
# You win
# -----------------------------------------------------
# Chose your attack {1: 'Tackle', 2: 'Vine Whip', 3: 'Solar Beam'}: 2
# Bulbasaur used Vine Whip to Squirtle
# It was efficient!!!
# -----------------------------------------------------
# Bulbasaur HP .................150
# Squirtle HP .................120
# -----------------------------------------------------
# What is your choice? You must choose one of them (rock, paper, scissors):  rock
# Cati choose Paper
# -----------------------------------------------------
# You Lose
# Squirtle used Water Gun to Bulbasaur
# But it was not efficient...
# -----------------------------------------------------
# Bulbasaur HP .................130
# Squirtle HP .................120
# -----------------------------------------------------
# What is your choice? You must choose one of them (rock, paper, scissors):  rock
# Cati choose Paper
# -----------------------------------------------------
# You Lose
# Squirtle used Tackle to Bulbasaur
# -----------------------------------------------------
# Bulbasaur HP .................120
# Squirtle HP .................120
# -----------------------------------------------------
# What is your choice? You must choose one of them (rock, paper, scissors):  paper
# Cati choose Scissors
# -----------------------------------------------------
# You Lose
# Cati won 3 times in a row!
# He can use Hydro Pump
# Squirtle used Hydro Pump to Bulbasaur
# Cati: Squirtle! I choose you! HYDRO PUMP.!!!!!!
# -----------------------------------------------------
# Bulbasaur HP ..................70
# Squirtle HP .................120
# -----------------------------------------------------
# What is your choice? You must choose one of them (rock, paper, scissors):  paper
# Cati choose Rock
# -----------------------------------------------------
# You win
# -----------------------------------------------------
# Chose your attack {1: 'Tackle', 2: 'Vine Whip', 3: 'Solar Beam'}: 2
# Bulbasaur used Vine Whip to Squirtle
# It was efficient!!!
# -----------------------------------------------------
# Bulbasaur HP ..................70
# Squirtle HP ..................90
# -----------------------------------------------------
# What is your choice? You must choose one of them (rock, paper, scissors):  scissors
# Cati choose Rock
# -----------------------------------------------------
# You Lose
# Squirtle used Water Gun to Bulbasaur
# But it was not efficient...
# -----------------------------------------------------
# Bulbasaur HP ..................50
# Squirtle HP ..................90
# -----------------------------------------------------
# What is your choice? You must choose one of them (rock, paper, scissors):  rock
# Cati choose Paper
# -----------------------------------------------------
# You Lose
# Squirtle used Water Gun to Bulbasaur
# But it was not efficient...
# -----------------------------------------------------
# Bulbasaur HP ..................30
# Squirtle HP ..................90
# -----------------------------------------------------
# What is your choice? You must choose one of them (rock, paper, scissors):  rock
# Cati choose Paper
# -----------------------------------------------------
# You Lose
# Cati won 3 times in a row!
# He can use Hydro Pump
# Squirtle used Hydro Pump to Bulbasaur
# Cati: Squirtle! I choose you! HYDRO PUMP.!!!!!!
# -----------------------------------------------------
# Bulbasaur HP .................-20
# Squirtle HP ..................90
# -----------------------------------------------------
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-092ba0f0b4c3> in <module>
#     240
#     241 print('...')
# --> 242 time.slppe(1)
#     243 print('...')
#     244 time.slppe(1)
#
# AttributeError: module 'time' has no attribute 'slppe'

# %%
print(f'{player}: {your_pokemon}! I choose you! {pokemon_skil[n_your_pokemon][3].upper()}.!!!!!!')
# Out:
# Luis: Charmander! I choose you! FIRE BLAST.!!!!!!

# %%
print(comp_special_skil)
# Out:
# 3

# %%
print(f'{your_pokemon} used {pokemon_skil[n_your_pokemon][3]} to {opponent_pokemon}')
print(f'{player}: {your_pokemon}! I choose you! {pokemon_skil[n_your_pokemon][3].upper()}.!!!!!!')
# Out:
# Charmander used Fire Blast to Bulbasaur
# Luis: Charmander! I choose you! FIRE BLAST.!!!!!!
